# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/MODULO_I/blob/main/Avalia%C3%A7%C3%A3o_Parcial_II_(AV2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time # Biblioteca para simular o tempo passado

# %%
print (" ---- INICIANDO O ALGORITMO DO BOLO ----")
# Out:
#  ---- INICIANDO O ALGORITMO DO BOLO ----

# %%
# 1. Variáveis: Separando os ingredientes e ferramentas
temperatura_forno = 0
forma_untada = True
tigela = [] # Uma lista vazia para colocar os ingredientes
massa_homogenea = False
tempo_forno = 40
palito_limpo = False

# %%
#  2. Entrada/Ações Simples
