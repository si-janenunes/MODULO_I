# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/MODULO-I/blob/main/Atividade_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CENTRO DE EDUCAÇÃO DE TECNOLOGIA DO AMAZONAS - IBC
#
# MANAUS 23 DE MARÇO DE 2026
#
# Curso Técnico em nível médio em Intreligência Artificial
#
# AlunA: Rojane Nunes

# %%
print('Olá Mundo!')
# Out:
# Olá Mundo!

# %%
2+3
# Out:
# 5

# %%
50 - 5*7
# Out:
# 15

# %%
(50 - 5*6)/2
# Out:
# 10.0

# %%
print (int ( 8/5)) # divisão com operandos inteiros, retorna resultado inteiro ( vs.2.7)
print (8./5)       # divisão com pelo menos um operando real, retorna resultado real ( vs.2.7)
# Out:
# 1
# 1.6

# %%
5**2 # 5 elevado ao quadrado
# Out:
# 25

# %%
59**-2
# Out:
# 0.0002872737719046251

# %%
# Lendo Binário
numero = 59
Resultado = bin(numero)
print (Resultado) # saida
# Out:
# 0b111011

# %%
# Calculadora
numero1 = 2
numero2 = 4


print(f"A soma de {numero1} e {numero2} é: {numero1 + numero2}")
print(f"A subtração entre {numero2} e {numero1} é: {numero2 - numero1}")
print(f"A multiplicção de {numero1} e {numero2} é: {numero1 * numero2}")
print(f"A divisão de {numero1} e {numero2} é: {numero1 / numero2}")
# Out:
# A soma de 2 e 4 é: 6
# A subtração entre 4 e 2 é: 2
# A multiplicção de 2 e 4 é: 8
# A divisão de 2 e 4 é: 0.5

# %%
print(int(10 + 10))
print(int(120 - 20))
print(int(9 * 3 ))
print(int(25 / 5))
# Out:
# 20
# 100
# 27
# 5
