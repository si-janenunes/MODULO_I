# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/M%C3%93DULO_I/15_05_gitOk_Atividade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Curso Técnico de Nível Médio em Inteligência Artificial - 2026
#
# Atividade-Avaliativa--15
#
#
# Módulo I - Linguagem em Pyton
#
# Aluna - Rojane Nunes Hermes

# %%
# Lista de fatiamento em ordenação
listadec = list(range(0,20,2))  # python3: o resultado da função 'range' é um objbeto 'range', precisa ser convertido em lista
print(listadec)                  # acessa todos os elementos
print(listadec[1:4])            # acessa do 1o. ao 3o. elementos
print(listadec [2:])           # acessa do 3o. ao penúltimo elementos
