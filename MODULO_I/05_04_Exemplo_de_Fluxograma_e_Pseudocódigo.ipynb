# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/05_04_Exemplo_de_Fluxograma_e_Pseudoc%C3%B3digo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exmplo de Fluxograma e Pseudocódigo

# %% [markdown]
# ![Exemplo Média.drawio.png](data:image/png;base64,...)

# %%
#minha descrição
Algoritmo Média
inicio #1 amarelo
var: N1,N2 media:real   #2 Azul
leia N1,N2 #3 Roxo
Média - ( N1 + N2) /2 #3 Roxo
se Média >=7 #4 laranja
então escreva (" Aprovado!") #5 verde saida 1
senao escreva ( " Reprovado ") # 4 e #6 laranja e vermelho saida 2
fim # amarelo

# %%
descrição da IA
Algoritmo VerificaMedia

// 1 – Início
Início

// 2 – Entrada das notas
Leia N1
Leia N2

// 3 – Cálculo da média
Media <- (N1 + N2) / 2

// 4 – Decisão
Se (Media >= 7) então
    // 5 – Saída: aprovado
    Escreva("Aprovado")
Senão
    // 6 – Saída: reprovado
    Escreva("Reprovado")
FimSe

// 7 – Fim
FimAlgoritmo

# %%
# Este foi feito por IA para rodar no Colab
# Programa para calcular a média de duas notas

n1 = float(input("Digite a primeira nota: "))
n2 = float(input("Digite a segunda nota: "))

media = (n1 + n2) / 2

print("Média:", media)

if media >= 7:
    print("Aprovado")
else:
    print("Reprovado")
# Out:
# Digite a primeira nota: 8
# Digite a segunda nota: 6
# Média: 7.0
# Aprovado
