# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/09_04_Atividade_Classifica%C3%A7%C3%A3o_de_idade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aluna - Rojane Nunes Hermes
#
# **Clasificação de Idade**

# %%
while True:
  try:
    idade = int(input("Digite sua idade: "))
    break
  except ValueError:
    print("Entrada inválida. Por favor, digite um número inteiro para a idade.")

if idade < 18:
  print("Conteúdo Restrito")
else:
  print("Conteúdo Liberado")

# %%
idade = int(input("Digite sua idade"))

if(idade > 0 ):
if (idade >80):
print ("Idade Invalida")
else:
if (idade <18):
  print (" Conteúdo Restrito")
  else:
print (" ")
else:
  print (" Idade Invalida")
