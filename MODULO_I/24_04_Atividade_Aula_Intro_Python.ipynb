# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/24_04_Atividade_Aula_Intro_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ECERCÌCIO

print ( " Ola Mundo!")
# Out:
#  Ola Mundo!

# %% [markdown]
# # Sentenças

# %%
x = 12
x = x + 100
print (x)
# Out:
# 112

# %%
x = 2            # atribuição de uma constante numérica à variável 'x'
print (x)
# Out:
# 2

# %%
x = x + 100      # atribuição de expressão aritmética à variável 'x'
print (x)        # função de apresentação de valor da variável 'x' (saída de dados)
# Out:
# 102

# %%
nome: str
idade: int
altura: float
genero: str
salario: float

nome =   "Rojane Nunes Hermes"
idade = 45
altura = 1.54
genero = "Feminino"
salario = 1000.00

print (nome)
print (idade)
print (altura)
print (genero)
print (salario)
# Out:
# Rojane Nunes Hermes
# 45
# 1.54
# Feminino
# 1000.0
