# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/16_04_Exemplo_calculo_de_Media.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculo_media (n1,n2):
    media=(n1+n2)/2
    return media

# %%
n1=float (input ("nota "))
n2=float (input("nota "))
media=float
media=calculo_media (n1,n2)
print (media)
# Out:
# nota 6
# nota 9
# 7.5

# %%
n1=int (input("nota "))
n2=int (input("nota "))
media=int
media=calculo_media (n1,n1)
if ( media >5 or <= 10 ):
 print (media)
 print ("recuperação")
elif (media <5 ):
  print (media)
  print (" Aprovado")
else:
  print (" Repetir Nota")
# Out:
#   File "/tmp/ipykernel_868/637873772.py", line 5
#     if ( media >5 or <= 10 ):
#                      ^
# SyntaxError: invalid syntax
