# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/17_03_Atividade1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exemplo de uso :

numero1 = 20
numero2 = 7

print(f"A soma de {numero1} e {numero2} é: {numero1 + numero2}")
print(f"A diferença entre {numero1} e {numero2} é: {numero1 - numero2}")
print(f"O produto de {numero1} e {numero2} é: {numero1 * numero2}")
print(f"O quociente de {numero1} e {numero2} é: {numero1 / numero2}")
print(f"A parte inteira da divisao de {numero1} por {numero2} é:")
print(f"O resto da divisao de {numero1} por {numero2} é: {numero1 - numero2}")
print(f"{numero1} elevado a {numero2} é {numero1 ** numero2}")
# Out:
# A soma de 20 e 7 é: 27
# A diferença entre 20 e 7 é: 13
# O produto de 20 e 7 é: 140
# O quociente de 20 e 7 é: 2.857142857142857
# A parte inteira da divisao de 20 por 7 é:
# O resto da divisao de 20 por 7 é: 13
# 20 elevado a 7 é 1280000000

# %% [markdown]
# import time
# print (time . ctime ())
