# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/04_05_Revis%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exemplo 1
idade = 17
PI = 3.141559
print (idade)
print(PI)

# %%
# Exemplo 2

nome = 'Ana'
peso = 52.5
aprovado = True

print(nome,peso,aprovado)

# %%
# Exemplo 3

print (type(10))
print (type(30.5))
print (type('Python'))

# %%
# Exemplo 4

nome = input ('Digite seu nome: ')
print  (  'Olá!,' , nome)

# %%
# Exemplo 5

print (10 / 3)
print (10 // 3)

# %%
# Exemplo 6

idade = 18
tem_ingresso = True
print (idade >= 18 and tem_ingresso)

# %%
# Exemplo 7

print nome

# %%
# Exemplo 8

x = 5
y = 8
print (x==5 , y == 9)

# %%
# Exemplo 9

a = 8
b = 2
print ( a / b)
print (a // b)
print (type(a))

# %%
# Exemplo 10

nota = 7
frequencia = 80
aprovado = nota >= 6 and frequencia >= 75
print (aprovado)
