# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/09_04_Atividade_Aula_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = input (" Digite sua idade")
autorização = sim
if (idade >= 18 and tem autorização == sim):
printe (" liberado")
else:
  print (" Não Liberado")

# %%
idade = imput (" Digite sua idade")
autorização == sim

if (idade >= 18 or tem autorização == sim):
  else:
    print (" Liberado")
# Out:
#   File "/tmp/ipykernel_724/3142562095.py", line 4
#     if (idade >= 18 or tem autorização == sim):
#         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
idade = input (" Digite sua idade")
autorização = sim
if (idade >= 18 and tem autorização == sim):
printe (" liberado")
else:
  print (" Não Liberado")

# %%
idade = input (" Digite sua idade")
autorização = sim
if (idade >= 18 and tem autorização == sim):
printe (" liberado")
else:
  print (" Não Liberado")
