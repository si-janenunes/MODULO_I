# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/05_04_Exercicio_Sensor_de_Temperatura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aluna -  Rojane Nunes Hermes
# Aluna -  Pauliana Saraiva

# %% [markdown]
# Início -
#
# Entrada = Leia Temperatura
#
# Temperatura > 25?
#
# Se não - Escreva Estável
#
# Se sim - Escreva Alerta de Temperatura
#
# Fim

# %%
Início -=


Entrada Escreva (" Digite Temperatura")

Leia Temperatura atual: (>25?)

Se Temperatura ( >25)

Então Escreva (" Alerta de Resfriar")

Senão Escreva (" Temepartura Estável")

 FimSe

Fim do Algoritmo
