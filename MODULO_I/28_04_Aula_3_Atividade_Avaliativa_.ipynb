# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/28_04_Aula_3_Atividade_Avaliativa_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Curso Técnico de Nível Médio em Inteligência Artificial - 2026
#
# Atividade Avaliativa -
#
# Aula 03 - 28 Abril/2026
#
# Módilo I - Linguagem em Pyton
#
# Aluna - Rojane Nunes Hermes

# %%
#Exemplo 01
print(15 == 15)
print(15 == 16)
print(type(True))
print( '' == True, '' == False, '' == None)
a = 'ok'
b = ' tchau'
print(a,b, a is b)
b = a
print(a, b, a is b)
a = 20
print(a, b, a is b)
a = 'ok'
print(a, b , a is b)
# Out:
# True
# False
# <class 'bool'>
# False False False
# ok  tchau False
# ok ok True
# 20 ok False
# ok ok True
