# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/14_04_Atividade_Revis%C3%A3o_Av2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lógica e automação

# %% [markdown]
# # 1) - Estruturas de Decisão Encadeadas:
# O Sistema do Laboratório agora precisa
# classificar a precisação dos modelos de IA.
# Escreva o psudocódigo que receba uma pontuação e exiba:
# "Exelente" se for maior ou igual a 90.
# " Esável" se estiver entre 70 e 89.
# " Em treinamento" se for menor que 70.

# %%
ponuação = float
pontuação = int ( input (" Digite a Pontuação" ) )
if (pontuação >= 90):
  print (" Exelente")
elif ( pontuação >= 70 and pontuação <= 90):
  print ("Estável")
else:
  print ("Em Treinamento")
# Out:
#  Digite a Pontuação120
#  Exelente

# %% [markdown]
# # 2) - Operadores Lógicos e Segurança:
# Modifique o controle de acesso do laboratório.
# O acesso "ADMIN" só deve ser liberado se o id for "ADMIN" E a chave_seguranca
# for igual a 1234. Caso o ID seja "ADMIN" mas a chave esteja incorreta, exiba "Alerta
# de Segurança". Se for "ALUNO", o acesso continua restrito.

# %%
user_password = string
passeword = string
