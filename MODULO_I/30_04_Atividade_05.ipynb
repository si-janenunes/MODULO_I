# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/30_04_Atividade_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Curso Técnico de Nível Médio em Inteligência Artificial - 2026
# *30 / Abril / 2026*
#
# Atividade 05
#
# Aula 05
#
# Módulo I - Linguagem em Pyton
#
# **Aluna - Rojane Nunes Hermes**

# %%
#Exemplo 1

peso, cumprimento, idade = 10.5, "boa tarde!", 20
print(cumprimento, peso,idade)
# Out:
# boa tarde! 10.5 20

# %%
#Exemplo 2

saudacoes = "boa tarde!"
peso = 50
cumprimento = 10.5
idade = 20

print (saudacoes)
print (peso)
print (cumprimento)
print (idade)
# Out:
# boa tarde!
# 50
# 10.5
# 20

# %%
#Exemplo 3

x = int(input ("Digite um valor inteiro = "))
print  ("Você digitou = ", x )
# Out:
# Digite um valor inteiro = 80
# Você digitou =  80

# %%
#Exemplo 4

entrada = input("Entre a Temperatura em Fahrenheit: ")
temperF = float(entrada)
temperC = (temperF - 32.0)*5/9
print("Farhenhit", temperF, "Celcius:", temperC)
# Out:
# Entre a Temperatura em Fahrenheit: 24.5
# Farhenhit 24.5 Celcius: -4.166666666666667

# %%
#Exemplo 5

entrada = input('Entre a Temperatura em Fahrenheit: ')
try:
    temperF = float(entrada)
    temperC = (temperF - 32.0)*5/9
    print("Fahrenheit:", temperF, "Celsius:", temperC)
except Exception as e:
    print(f"Favor digitar um valor numérico! \nErro: {e}")
# Out:
# Entre a Temperatura em Fahrenheit: 5.5
# Fahrenheit: 5.5 Celsius: -14.722222222222221

# %%
#DESAFIO

temperF = None
while type(temperF) != float:
    entrada = input('Entre a temperatura em Fahrenheit: ')
    try:
      temperF = float(entrada)
    except:
      print("Favor digitar um valor numérico!")
temperC = (temperF - 32.0)*5/9
print(" Fahrenheit:", temperF, "Celcius", temperC)
# Out:
# Entre a temperatura em Fahrenheit: 6
#  Fahrenheit: 6.0 Celcius -14.444444444444445

# %%
#ATIVIDADE AVALIATIVA PRÁTICA: AULA 05

print("\n--- Exemplo de if -elif - else ---")
idade = 17
if idade < 13:
    print("Você é uma criança.")
elif idade < 18:
    print(" Você é um adolescente.")
else:
    print(" Você é um adulto.")

print("\n--- Exemplo de Estrutura Aninhada (Nested if)---")
usuario_logado = True
admin = True

if usuario_logado:
    print("Usuério está Logado.")
    if admin:
       print("Usuário é um administrador.")
       permissao = "Toral"
    else:
        print("Usuário não é um usuário.")
        permissão = "Limitada"
    print(f"Permissão do usuário: {permissao}")
else:
    print("Usuário não está logado. Por favor, Faça Login.")
# Out:
# --- Exemplo de if -elif - else ---
#  Você é um adolescente.
#
# --- Exemplo de Estrutura Aninhada (Nested if)---
# Usuério está Logado.
# Usuário é um administrador.
# Permissão do usuário: Toral
