# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/17_04_Atividade_Oficina_Aula7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Orçamento = float (input( " Digite seu Orçamento ="  ) )
Urgência = int (input(" Digite sua Urgência de 1 a 5 ="  ))
if (Orçamento > 10000 and Urgência >=4):
    print (" Lead Vip")
elif(Orçamento > 5000 or Urgência == 5):
    print (" Lead Prioritário")
else:
   print (" Lead Padão")
# Out:
#  Digite seu Orçamento =12000
#  Digite sua Urgência de 1 a 5 =3
#  Lead Prioritário
