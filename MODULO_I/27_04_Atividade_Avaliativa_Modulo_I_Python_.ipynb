# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/27_04_Atividade_Avaliativa_Modulo_I_Python_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Curso Técnico de Nível Médio em Inteligência Artificial - 2026
# **Atividade Avaliativa -**
#
#
# Aula 02 - 27 Abril/2026
#
#
# Módilo I - Linguagem em Pyton
#
# Aluna - Rojane Nunes Hermes

# %%
# atividade 01
nome = input("Digite seu nome: ")
cidade = input("Digite sua Cidade: ")
ano_de_nascimento = int(input("Digite seu ano de Nascimento: "))
idade = 2026 - ano_de_nascimento
print (f"Olá, {nome}! Você mora em {cidade} e tem aproximadadmente {idade} amos.")
# Out:
# Digite seu nome: Rojane
# Digite sua Cidade: Manaus
# Digite seu ano de Nascimento: 1981
# Olá, Rojane! Você mora em Manaus e tem aproximadadmente 45 amos.

# %%
# atividade 02

largura = float
comprimento = float
valor = float
area = float
preco = float

largura = float(input("Digite a largura do terreno: "))
comprimento = float(input("Digite o comprimento do terreno: "))
valor = float(input("Digite o valor do metro quadrado: "))

area = largura * comprimento

print(f"Area do terreno = {area:.2f}")

preco = area * valor

print(f"Preco do terreno = {preco:.2f}\n")
# Out:
# Digite a largura do terreno: 10
# Digite o comprimento do terreno: 30
# Digite o valor do metro quadrado: 200
# Area do terreno = 300.00
# Preco do terreno = 60000.00

# %%
# atividade 02

largura = float
comprimento = float
valor = float
area = float
preco = float

largura = float(input("Digite a largura do terreno: "))
comprimento = float(input("Digite o comprimento do terreno: "))
valor = float(input("Digite o valor do metro quadrado: "))

area = largura * comprimento

print(f"Area do terreno = {area:.2f}")

preco = area * valor

print(f"Preco do terreno = {preco:.2f}\n")
# Out:
# Digite a largura do terreno: 12
# Digite o comprimento do terreno: 20
# Digite o valor do metro quadrado: 150
# Area do terreno = 240.00
# Preco do terreno = 36000.00
