# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/09_04_Atividade_Saque_Bancario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Atividade Saque Bancário**
#
# **Aluna: Rojane Nunes**
# #

# %%
saldo = int (imput deposito)
saque = int(input (" Digite Valor do Saque"))


if saque <100:
else (saldo - saque):
   print (" Retire seu dinheiro")

if saque >100:
    print (" Saldo insuficiente")
# Out:
#   File "/tmp/ipykernel_24499/2262669690.py", line 6
#     else (saldo - saque):
#     ^
# IndentationError: expected an indented block after 'if' statement on line 5
