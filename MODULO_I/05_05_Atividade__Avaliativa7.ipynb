# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/05_05_Atividade__Avaliativa7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Curso Técnico de Nível Médio em Inteligência Artificial - 2026
#
# Atividade - Avaliativa 7
#
# Módilo I - Linguagem em Pyton
#
# Aluna - Rojane Nunes Hermes

# %%
# Exemplo 1

10 + 20 *3
42 / 30
(94 + 2) * 6 - 1
# Out:
# 575

# %%
# Exempolo 2

10 / 3 * 10 **2 + 1 - 10 * 4/2
# Out:
# 314.33333333333337

# %%
#Exemplo  3

nome = input("Digite seu nome: ")
print(f"Olá, {nome}!")
# Out:
# Digite seu nome: Rojane
# Olá, Rojane !

# %%
#Exemplo 4

a = 3
b = 5
resultado = (2a * 3b)
print = (f" Resultado: , {resultado} ")

# %%
#Exemplo 5

n1 = 10
n2 = 20
n3 = 40
total = n1 + n2 + n3
print (total)
# Out:
# 70
