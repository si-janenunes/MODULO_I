# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/Lista_2_Exerc%C3%ADcio_Pr%C3%A1tico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Curso Técnico de Nível Médio em Inteligência Artificial - 2026
#
# Lista 2 de Exercício Prático
#
# Módilo I - Linguagem em Pyton
#
# Aluna - Rojane Nunes Hermes

# %% [markdown]
# 1. **Complete a tabela a seguir, marcando inteiro ou ponto flutuante dependendo do
# número apresentado. **
#
# 5 [ x ] inteiro [ ] ponto flutuante
#
# 5.0 [ ] inteiro [ x ] ponto flutuante
#
# 4.3 [ ] inteiro [ x ] ponto flutuante
#
# -2 [ x ] inteiro [ ] ponto flutuante
#
# 100 [ x ] inteiro [ ] ponto flutuante
#
# 1.333 [ ] inteiro [ x ] ponto flutuante

# %%
# 2. Desenvolver uma expressão que será utilizada para decidir se um aluno foi ou
# não aprovado. Para ser aprovado, todas as médias do aluno devem ser maiores
# que 7. Considere que o aluno cursa apenas três matérias, e que a nota de cada
# uma está armazenada nas seguintes variáveis: matéria1, matéria2 e matéria3.
media = 70
materia1 = 90
materia2 = 30
materia3 = 30
media = ((materia1 + materia2 + materia3 ) /2)
if (media > 70):
  print("APROVADO",media)
else:
  print("REPROVADO",media)

# %% [markdown]
# 3. Complete a tabela a seguir, respondendo True ou False. Considere a = 4, b =
# 10, c = 5.0, d = 1 e f = 5.
#
# Expressão Resultado Expressão Resultado
#
# a == c [ ] True [ x ] False b > a [ x ] True [ ] False
#
# a < b [ x ] True [ ] False c >= f [ x ] True [ ] False
#
# d > b [ ] True [ x ] False f >= c [ ] True [ ] False
#
# c != f [ ] True [ x ] False c <= c [ ] True [ ] False
#
# a == b [ ] True [ x ] False c <= f [ ] True [ ] False
#
# c < d [ ] True [ x ] False f >= b [ ] True [ ] False

# %% [markdown]
# Complete a tabela a seguir utilizando a = True, b = False e c = True.
#
# Expressão Resultado Expressão Resultado
#
# a and a [ x ] True [ ] False a or c [ ] True [ ] False
#
# b and b [ ] True [ x ] False b or c [ ] True [ ] False
#
# not c [ x ] True [ ] False c or a [ x ] True [ ] False
#
# not b [ ] True [ x ] False c or b [ x ] True [ ] False
#
# Not a [ ] True [ ] False c or c [ ] True [ ] False
#
# a and b [ ] True [ x ] False b or b [ x ] True [ ] False
#
# b and c [ ] True [ x ] False

# %% [markdown]
# Calcule o resultado da expressão A > B and C or D, utilizando os valores da
# tabela a seguir.
#
# - A-| -B  -| -C    -|   -D    -|-Resultado
#
# -01 | 02  |-True   |-False     -|
#
# -10 | 03  |-False  |-False    -|
#
# -05 | 01  |-True   |-True      -|
