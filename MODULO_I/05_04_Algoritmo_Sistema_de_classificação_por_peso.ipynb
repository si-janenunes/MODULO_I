# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/05_04_Algoritmo_Sistema_de_classifica%C3%A7%C3%A3o_por_peso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Aividade - Algoritmo Sistema de classificação por peso
#
# * Aluna Rojane Nunes Hermes *

# %% [markdown]
# ![Atividade - Um sistema de classificação por peso .drawio (1).png](data:image/png;base64,...)

# %%
Algoritmo Sistema de classificação por peso

Inicio

escreva ("Coloque o material na Balança")

Ler peso

Se o material >= 500g

Então Escreva ( "Enviar ao Setor de Metais" )

Senão  Escreva ( "Enviar ao Setor de Plásticos" )

      Fim
