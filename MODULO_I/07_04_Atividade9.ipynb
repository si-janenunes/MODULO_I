# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/CURSO-IA-CETAM-2026/blob/main/MODULO_I/07_04_Atividade9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Curso Técnico de Nível Médio em Inteligência Artificial - 2026
#
# Atividade-Avaliativa--9
#
# Módulo I - Linguagem em Pyton
#
# Aluna - Rojane Nunes Hermes

# %%
#Exercício dia 07/04- Questão 6

for i in range(1,11):
  print(i)

# %%
#Exercício dia 07/04-Questão 7

x = 0
while (1,6):
  if ==
  break

  print (x)
  x = x + 1

# %%
#Exercício dia 07/04-Questão 8

for n in range (1, 6 ):
  if n == 3:
    break
  print (n)

# %%
#Exercício dia 07/04-Questão 9

x = 0
while x < 4:
  print (x)
  x = x +1

# %%
#Exercício dia 07/04 - Questão 11

for numero in range (0, 6): # contagem de 0 a 6
  print(numero)
